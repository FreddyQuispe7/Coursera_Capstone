# %% [markdown]
# Final Project of Coursera Capstone course
# Developed by Freddy Alexander Quispe Torres

# %%
import pandas as pd
import numpy as np

# %%
print("¡Hola, Proyecto Final del Curso!")
# Out:
# ¡Hola, Proyecto Final del Curso!
